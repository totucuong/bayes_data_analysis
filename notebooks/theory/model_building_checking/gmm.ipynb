# %%
from __future__ import print_function
import os
from collections import defaultdict
from sklearn.cluster import MiniBatchKMeans
import numpy as np
import scipy.stats
import torch
from torch.distributions import constraints
from matplotlib import pyplot
# %matplotlib inline

import pyro
import pyro.distributions as dist
from pyro.optim import Adam
from pyro.infer import SVI, TraceEnum_ELBO, config_enumerate

smoke_test = ('CI' in os.environ)
pyro.enable_validation(True)

# %%
K=4
true_weight = torch.tensor([0.06, 0.4, 0.4, 0.04])
true_mu = torch.tensor([2., 20., 45., 60.])
true_scale= torch.tensor([10., 5., 1., 20.])
N= 100000

# %%
assignment = dist.Categorical(true_weight).expand_by([N])()
data = dist.Normal(true_mu[assignment], true_scale[assignment])()

# %%
pyplot.hist(data, bins=100, alpha=0.4, color='r');

# %%
K = 4
def init_locs(data, K):
    cluster = MiniBatchKMeans(batch_size=100, n_clusters=K)
    cluster.fit(data.view(len(data), -1))
    return torch.tensor(cluster.cluster_centers_.squeeze()).type(torch.float32)

mus = init_locs(data, K)

def model(data):
    # Global parameters.
    weights = pyro.param('weights', torch.ones(K) / K, constraint=constraints.simplex)
    locs = pyro.param('locs', mus)
    scales = pyro.param('scales', 0.5 * torch.ones(K), constraint=constraints.positive)

    with pyro.iarange('data', len(data)) as ind:
        # Local variables.
        assignment = pyro.sample('assignment',
                                 dist.Categorical(weights).expand_by([len(ind)]))
        pyro.sample('obs', dist.Normal(locs[assignment], scales[assignment]), obs=data.index_select(0, ind))

@config_enumerate(default='parallel')
def guide(data):
    with pyro.iarange('data', len(data), subsample_size=10000) as ind:
        # Local parameters.
#         print('sampled index', ind)
        assignment_probs = pyro.param('assignment_probs', torch.ones(len(data), K) / K,
                                      constraint=constraints.unit_interval)
        pyro.sample('assignment', dist.Categorical(assignment_probs[ind]))

# %%
optim = pyro.optim.Adam({'lr': 0.02, 'betas': [0.9, 0.99]})
inference = SVI(model, config_enumerate(guide, 'parallel'), optim,
                loss=TraceEnum_ELBO(max_iarange_nesting=1))

# %%
pyro.set_rng_seed(1)      # Set seed to make results reproducible.
pyro.clear_param_store()  # Clear stale param values.

# Register hooks to monitor gradient norms.
gradient_norms = defaultdict(list)
inference.loss(model, guide, data)  # Initializes param store.
for name, value in pyro.get_param_store().named_parameters():
    value.register_hook(lambda g, name=name: gradient_norms[name].append(g.norm().item()))

losses = []
for i in range(5000 if not smoke_test else 2):
    loss = inference.step(data)
    losses.append(loss)
    if (i % 100 == 0):
        print('loss at {}th epoch is {}'.format(i, loss))
# Out:
# loss at 0th epoch is 195825120.0
# loss at 100th epoch is 14648484.0
# loss at 200th epoch is 5365714.5
# loss at 300th epoch is 2691851.25
# loss at 400th epoch is 1571848.625
# loss at 500th epoch is 1031634.0
# loss at 600th epoch is 751096.75
# loss at 700th epoch is 602332.5
# loss at 800th epoch is 522702.65625
# loss at 900th epoch is 478450.96875
# loss at 1000th epoch is 455895.34375
# loss at 1100th epoch is 442583.15625
# loss at 1200th epoch is 432840.375
# loss at 1300th epoch is 428866.125
# loss at 1400th epoch is 424648.375
# loss at 1500th epoch is 423521.5625
# loss at 1600th epoch is 421185.84375
# loss at 1700th epoch is 417871.9375
# loss at 1800th epoch is 411236.71875
# loss at 1900th epoch is 400062.96875
# loss at 2000th epoch is 389748.1875
# loss at 2100th epoch is 379101.0625
# loss at 2200th epoch is 371668.84375
# loss at 2300th epoch is 359998.375
# loss at 2400th epoch is 353047.9375
# loss at 2500th epoch is 350185.125
# loss at 2600th epoch is 348375.25
# loss at 2700th epoch is 341490.90625
# loss at 2800th epoch is 342952.0
# loss at 2900th epoch is 340726.65625
# loss at 3000th epoch is 338765.875
# loss at 3100th epoch is 336782.46875
# loss at 3200th epoch is 336664.03125
# loss at 3300th epoch is 331776.6875
# loss at 3400th epoch is 334779.90625
# loss at 3500th epoch is 333874.65625
# loss at 3600th epoch is 335941.78125
# loss at 3700th epoch is 332990.03125
# loss at 3800th epoch is 337714.15625
# loss at 3900th epoch is 335398.875
# loss at 4000th epoch is 335045.21875
# loss at 4100th epoch is 334173.6875
# loss at 4200th epoch is 333261.40625
# loss at 4300th epoch is 336902.1875
# loss at 4400th epoch is 333124.15625
# loss at 4500th epoch is 336489.96875
# loss at 4600th epoch is 334528.09375
# loss at 4700th epoch is 335094.15625
# loss at 4800th epoch is 336821.1875
# loss at 4900th epoch is 334312.34375

# %%
pyplot.figure(figsize=(10,3), dpi=100).set_facecolor('white')
pyplot.plot(losses)
pyplot.xlabel('iters, lr=0.001')
pyplot.ylabel('loss')
pyplot.yscale('log')
pyplot.title('Convergence of SVI');
pyplot.savefig('elbo_svi_lr_0001.png')

# %%
losses[-1]
# Out:
# 334524.4375

# %%
len(gradient_norms['locs'])
# Out:
# 5000

# %%
pyplot.figure(figsize=(10,4), dpi=100).set_facecolor('white')
for name, grad_norms in gradient_norms.items():
    pyplot.plot(grad_norms[:1000], label=name)
pyplot.xlabel('iters')
pyplot.ylabel('gradient norm')
pyplot.yscale('log')
pyplot.legend(loc='best')
pyplot.title('Gradient norms during SVI');

# %%
N
# Out:
# 100000

# %%
weights = pyro.param('weights')
locs = pyro.param('locs')
scales = pyro.param('scales')
print('weights = {}'.format(weights.data.numpy()))
print('locs = {}'.format(locs.data.numpy()))
print('scales = {}'.format(scales.data.numpy()))
# Out:
# weights = [0.4520024  0.41048366 0.09722731 0.04028661]
# locs = [45.000248 20.111408  7.014477 61.62981 ]
# scales = [ 0.9800417  4.8925667 12.315252  19.422934 ]

# %%
weights.sum()
# Out:
# tensor(1.)

# %%
assignment = dist.Categorical(weights).expand_by([N])()
syn = dist.Normal(locs[assignment], scales[assignment])()

# %%
pyplot.hist(syn.detach().numpy(), bins=100, alpha=0.2, color='b', label='synthetic');
pyplot.hist(data+10, bins=100, alpha=0.2, color='r', label='real right-shifted by 10');
pyplot.legend();

# %%
true_weight,true_mu , true_scale
# Out:
# (tensor([ 0.0600,  0.4000,  0.4000,  0.0400]),
#  tensor([  2.,  20.,  45.,  60.]),
#  tensor([ 10.,   5.,   1.,  20.]))

# %% [markdown]
# # Lesson learnt
#
# 1. The weights of components should be well-balanced. Otherwise it is very hard to capture all the modes.
# 2. The greater data variance is the large subsample size should be during training.
